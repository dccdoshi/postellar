# %%
import pandas as pd 
import matplotlib.pylab as plt 
import numpy as np

df = pd.read_pickle("../data/SPIRou04_val.df")
idxs = [6,41, 0,166, 223]

# %%
len(df['Broadened'].iloc[0])
# Out:
# 18746

# %%
plt.figure(figsize=(15,5))
count = 0
for i in idxs:

    plt.plot(df['Wavelength'].iloc[i][3:-4],df['Final'].iloc[i][3:-4]+count,label=str(df['teff'].iloc[i]))
    count+=1

plt.xlim(1006.5,1039)
# plt.xlim(1280,1320)
plt.legend()

# %%
df['Wavelength'].iloc[0][3:-3]
# Out:
# array([1.28074924e+03, 1.28075138e+03, 1.28075351e+03, ...,
#        1.32124820e+03, 1.32125040e+03, 1.00000000e+00])

# %%
df.iloc[6]
# Out:
# teff                                                                 2300
# logg                                                                  1.0
# metal                                                                 1.0
# alpha                                                                 0.0
# Spectrum                [18498445107839.29, 19743416425825.574, 205909...
# Normalization_Factor                                17618525183250.765625
# Normalized              [1.049942882019718, 1.1206055115552385, 1.1687...
# Broadened               [0.6444750752276602, 0.7753803035296565, 0.896...
# Final                   [1.0, 1.0, 1.0, 0.6444750752276602, 0.77538030...
# Wavelength              [1.0, 1.0, 1.0, 1280.7492413654045, 1280.75137...
# Name: 26, dtype: object

# %%
df=df.reset_index()

# %%
df[df['teff']==2700]
# Out:
#      index  teff  logg  metal  alpha  \
# 8      437  2700   0.0   -0.5    0.0
# 16     469  2700   2.0   -3.0    0.0
# 41     509  2700   4.0   -0.5    0.0
# 63     452  2700   1.0   -2.0    0.0
# 78     472  2700   2.0   -1.0    0.0
# 84     488  2700   3.0   -2.0    0.0
# 95     463  2700   1.5   -1.0    0.0
# 143    441  2700   0.5   -4.0    0.0
# 192    524  2700   5.0   -2.0    0.0
# 200    484  2700   2.5    0.5    0.0
# 235    502  2700   3.5    0.5    0.0
# 261    520  2700   4.5    0.5    0.0
# 266    492  2700   3.0    0.0    0.0
# 284    455  2700   1.0   -0.5    0.0
# 309    508  2700   4.0   -1.0    0.0
# 347    510  2700   4.0    0.0    0.0
# 349    474  2700   2.0    0.0    0.0
# 356    459  2700   1.5   -4.0    0.0
# 378    466  2700   1.5    0.5    0.0
#
#                                               Spectrum  Normalization_Factor  \
# 8    [21936887636049.527, 22370790793483.91, 225943...          2.171481e+13
# ...
